# %%
import pandas as pd
import numpy as np

# %%
data_df = pd.read_csv('../raw_data/Sample_data.csv')
data.head()
data_df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 200 entries, 0 to 199
# Data columns (total 15 columns):
#  #   Column              Non-Null Count  Dtype
# ---  ------              --------------  -----
#  0   _sdc_source_key_id  200 non-null    int64
#  1   sku                 197 non-null    object
#  2   date                200 non-null    object
#  3   item price          200 non-null    int64
#  4   item quantity       200 non-null    int64
#  5   line-item discount  200 non-null    float64
#  6   price_qty           200 non-null    float64
#  7   vendor              200 non-null    object
#  8   title               200 non-null    object
#  9   product_type        195 non-null    object
#  10  tags                185 non-null    object
#  11  email               200 non-null    object
#  12  gender              200 non-null    object
#  13  age                 193 non-null    float64
#  14  city                200 non-null    object
# ...

# %%
data_tags_df = data_df[['vendor','tags','product_type']]

# %%
data_tags_df = data_tags_df.dropna()
data_tags_df = data_tags_df.sort_values(['tags'])
data_tags_df['tags'].unique()
# Out:
# array(['28, 30, 32, 33, 34, 36, AEOMensJeans, Men, Shorts',
#        '30, 32, 34, 38, 40, Men', '30, 32, 34, Men',
#        '32, 34, 36, 38, 40, Men', '32, 34, 36, 38, Women',
#        '34, 36, 38, Women', 'Bag', 'Bath', 'Bathing',
#        'Black, Toughened Non-Stick', 'Body Butter', 'Body Lotion',
#        'Body Mist', 'Body Scrub', 'Body Wash', 'Body Yogurt',
#        'Bowl, Cappuccino', 'Bowl, Cayenne', 'Bowl, Dijon',
#        'Bowl, Elysees Yellow', 'Bowl, Flame', 'Bowl, Palm', 'Bowl, White',
#        'Calvin Klein, Giftset', 'Cappuccino, Mugs & Cup',
#        'Cappuccino, Plate', 'Case', 'Cerise, Trivet', 'Cleansing',
#        'Coast Blue, Kitchen Essentials', 'Coastal Blue, Mugs & Cup',
#        'Concealer', 'Cool Mint, Mugs & Cup', 'Daily Cleansing',
#        'Day Cream', 'Dijion, Mugs & Cup', 'Dijon, Dish',
#        'Dijon, Mugs & Cup', 'Dish, Dune', 'Dish, Lilac', 'Dish, Soleil',
#        'Dish, White', 'EDT',
#        'EU 31-33, EU 33-36, EU 36-38, Junior (aged 6-14)',
# ...

# %% [markdown]
# ## work on tags | type of product and gender

# %%
data_tags_df['gender'] = '__'
data_tags_df['type_of_product'] = '__'
data_tags_df['tags'] = data_tags_df["tags"].str.replace(',',' ')


data_tags_df.loc[data_tags_df["tags"].str.contains('[\s|][Mm]en'),'gender'] = 'men'
data_tags_df.loc[data_tags_df["tags"].str.contains('[\s|][Ww]omen'),'gender'] = 'women'
data_tags_df.loc[data_tags_df["tags"].str.contains('[\s|][Jj]unior'),'gender'] = 'children'
data_tags_df.loc[data_tags_df["tags"].str.contains('\d{2}'),'type_of_product'] = 'clothes'
data_tags_df.loc[data_tags_df["tags"].str.contains('[\s|]X*S[\s|]'),'type_of_product'] = 'clothes'
data_tags_df.loc[data_tags_df["tags"].str.contains('[\s|]M[\s|]'),'type_of_product'] = 'clothes'
data_tags_df.loc[data_tags_df["tags"].str.contains('[\s|]X*L[\s|]'),'type_of_product'] = 'clothes'
data_tags_df.loc[data_tags_df["product_type"].str.contains('Watershorts'),'type_of_product'] = 'clothes'


data_tags_df.loc[data_tags_df["vendor"].str.contains('LeCreuset'),'type_of_product'] = 'kitchen'
data_tags_df.loc[data_tags_df["vendor"].str.contains('LeCreuset'),'gender'] = 'unisex'
data_tags_df.loc[data_tags_df["vendor"].str.contains('Le Creuset'),'type_of_product'] = 'kitchen'
data_tags_df.loc[data_tags_df["vendor"].str.contains('Le Creuset'),'gender'] = 'unisex'
data_tags_df.loc[data_tags_df["vendor"].str.contains('StojoStasher'),'type_of_product'] = 'kitchen'
data_tags_df.loc[data_tags_df["vendor"].str.contains('StojoStasher'),'gender'] = 'unisex'
data_tags_df.loc[data_tags_df["tags"].str.contains('Unisex'),'type_of_product'] = 'kitchen'
data_tags_df.loc[data_tags_df["tags"].str.contains('Unisex'),'gender'] = 'unisex'


data_tags_df.loc[data_tags_df["product_type"].str.contains('Bath & Body'),'type_of_product'] = 'bath_body'
data_tags_df.loc[data_tags_df["product_type"].str.contains('Fragrance'),'type_of_product'] = 'bath_body'
data_tags_df.loc[data_tags_df["vendor"].str.contains('The Body Shop'),'type_of_product'] = 'bath_body'
data_tags_df.loc[data_tags_df["vendor"].str.contains('Dermatory'),'type_of_product'] = 'bath_body'
data_tags_df.loc[data_tags_df["product_type"].str.contains('Dermatory'),'gender'] = 'unisex'
data_tags_df.loc[data_tags_df["product_type"].str.contains('Bath & Body'),'gender'] = 'unisex'
data_tags_df.loc[data_tags_df["product_type"].str.contains('Fragrance'),'gender'] = 'unisex'
data_tags_df.loc[data_tags_df["vendor"].str.contains('The Body Shop'),'gender'] = 'unisex'


data_tags_df.loc[data_tags_df["tags"].str.contains('[\s|][Bb]ag'),'type_of_product'] = 'accessory'
data_tags_df.loc[data_tags_df["product_type"].str.contains('Goggles'),'type_of_product'] = 'accessory'
data_tags_df.loc[data_tags_df["tags"].str.contains('[\s|][Bb]ag'),'gender'] = 'unisex'
data_tags_df.loc[data_tags_df["product_type"].str.contains('Goggles'),'gender'] = 'unisex'


data_tags_df.loc[data_tags_df["vendor"].str.contains('Qwehli'),'type_of_product'] = 'food'
data_tags_df.loc[data_tags_df["vendor"].str.contains('Qwehli'),'gender'] = 'food'


data_tags_df.loc[data_tags_df["product_type"].str.contains('Home Electronics'),'type_of_product'] = 'home_appliance'
data_tags_df.loc[data_tags_df["product_type"].str.contains('Home Electronics'),'gender'] = 'unisex'


data_tags_df[(data_tags_df['type_of_product'] == '__') | (data_tags_df['gender'] == '__')]

# data_tags_df.head(60)
# Out:
#                   vendor                  tags        product_type gender  \
# 121  JosephJoseph-Online               Bathing           Household     __
# 156  Native Union-Online                  Case    Tech Accessories     __
# 72         Goodal-Online             Cleansing              Goodal     __
# 174        Orlane-Online       Daily Cleansing  Cleansing & Lotion     __
# 115  JosephJoseph-Online           Kitchenware           Household     __
# 68           Gaja-Online  MACAUFORBIDDEN  Wine            Beverage     __
# 49         Orlane-Online             Must Have               Serum     __
# 16         Risoli-Online             Non-Stick         Kitchenware     __
# 93         Goodal-Online            Sheet Mask              Goodal     __
# 104        Goodal-Online            Sheet Mask              Goodal     __
# 105        Goodal-Online            Sheet Mask              Goodal     __
# 106       Mustela-Online          Skincare Set         Baby & Kids     __
#
# ...
