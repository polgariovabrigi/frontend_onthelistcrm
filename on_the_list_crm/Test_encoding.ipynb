# %%
import pandas as pd
import numpy as np

#read data 
def get_data():
    #load data
    data_df = pd.read_csv('../raw_data/data_400_000_rows_clean_df.csv')
    #change the data        
    for column in data_df.columns:
        if data_df[column].dtype == 'O':
            data_df[column] = data_df[column].str.lower()
    return data_df

# %%
data = get_data()

# %%
data.head(20)
# Out:
#     Unnamed: 0      order_ID      item_ID      date   price  quantity  \
# 0       392094  2.713650e+12  4.97317e+12  13-10-20   200.0         1
# 1       840180  4.135400e+12   6.3087e+11  15-09-21   140.0         1
# 2       486909  3.151910e+12  7.39581e+11  29-12-20   100.0         1
# 3       539398  3.217110e+12  9.00621e+12  05-02-21  1112.0         5
# 4       465546  3.129150e+12  4.06206e+12  15-12-20   200.0         1
# 5       418453  2.774390e+12   8076633241  03-11-20  7290.0         1
# 6       720660  3.853800e+12  1.92333e+11  08-06-21    95.0         1
# 7       659269  3.746730e+12  4.89452e+12  16-04-21  1122.0         1
# 8       362341  2.645240e+12  3.33822e+12  24-09-20   204.0         2
# 9       744894  3.993400e+12  5.01212e+12  13-07-21   399.0         1
# 10      542112  3.226960e+12  6.97171e+12  09-02-21    78.0         1
# 11      691039  3.789510e+12  9.00975e+12  07-05-21   165.0         1
# 12      770772  4.052500e+12  8.05865e+12  04-08-21    50.0         1
# 13      405879  2.752240e+12  3.42348e+12  22-10-20   380.0         1
# 14      515312  3.197470e+12  3.34044e+12  25-01-21   289.0         1
# 15      594841  3.677340e+12  4.89468e+12  16-03-21   169.0         2
# 16      302298  2.558750e+12  4.89518e+12  24-08-20    91.5         1
# 17      379748  2.676370e+12   8.8908e+11  05-10-20   450.0         1
# 18      192457  2.343120e+12       460061  04-06-20  1470.0         1
# 19      765299  4.037020e+12   7.6125e+12  30-07-21  1395.0         1
#
#     discount  final_price                        vendor  \
# 0       0.00       200.00                 kanebo-online
# 1       0.00       140.00            le creuset-offline
# 2       0.00       100.00               borghese-online
# 3    1870.00      3690.00                 riedel-online
# 4       0.00       200.00                 adidas-online
# 5       0.00      7290.00             balenciaga-online
# 6       0.00        95.00               clinique-online
# 7     112.20      1009.80                   sht-offline
# 8       0.00       408.00                  phyto-online
# 9       0.00       399.00                lacoste-online
# 10      0.00        78.00  mariedalgar_and_velds-online
# 11     24.75       140.25                wolford-online
# 12      0.00        50.00              moleskine-online
# 13      0.00       380.00               shiseido-online
# 14      0.00       289.00            privateshop-online
# 15      0.00       338.00                 vossen-online
# 16     18.30        73.20                   pure-online
# 17     90.00       360.00                   dvf-offline
# 18      0.00      1470.00                 watson-online
# 19    348.75      1046.25                 bally-offline
#
#                          customer_ID  gender   age     nationality  \
# 0   0a84fe260bbd218cce7676123deb4db0  female  27.0   hong kong sar
# 1   ec42aa7b76d25011f21ddb624844857f    male  35.0   hong kong sar
# 2   c69fc08214b4afe8ccc4048e5c9f59e9  female  46.0   hong kong sar
# 3   98c279d4100a1153ebf3957a04874d5a  female  30.0   hong kong sar
# 4   45615d4e491fecfcc6f7963bde8b3607  female  39.0   hong kong sar
# 5   c90e60591458430648ae688d76f389fd  female  38.0   hong kong sar
# 6   02e4c986fff417fb7a88fc79f41cbf94  female  49.0   hong kong sar
# 7   b9d188c91f59ad76d0688a58184c12b5  female  35.0   hong kong sar
# 8   4e28972e3c0e3e608109addf3ca19d82  female  32.0   hong kong sar
# 9   c5a9af14c690a01e13885edf7d1c9673  female  38.0   hong kong sar
# 10  e36c8c6a846ecabb18f7741f7a4ba730  female  52.0   hong kong sar
# 11  2713ac432d408e247353019c5675e9ec  female  49.0  american samoa
# 12  2827462553d536e36e1ef3f83792cdb9  female  34.0   hong kong sar
# 13  fc0e755d2b6082908663dd61144870f0  female  31.0   hong kong sar
# 14  2c781c66939091c818fd086fd14ab1bb  female  44.0   hong kong sar
# 15  c577fceebdc386ae6e2d6e81612b7822  female  41.0   hong kong sar
# 16  69ca777552c2a36e2a0a7eca1574282c  female  42.0   hong kong sar
# 17  92c484ae1f55df0e5011123ceed660ac  female  50.0   hong kong sar
# 18  e24a1f3cb17bfd899cbf87081752eaed    male  48.0   hong kong sar
# 19  d535d75e93556a2f2748d95f72ccddb7    male  44.0   hong kong sar
#
#    premium_status           district   on_off product_gender product_cat
# 0               n          yuen long   online         unisex   bath_body
# 1               n           southern  offline         unisex     kitchen
# 2               n              north   online         unisex   bath_body
# 3               n         kwai tsing   online         unisex        home
# 4               n           southern   online         unisex     clothes
# 5               y  central & western   online          women   accessory
# 6               n           southern   online         unisex   bath_body
# 7               n  central & western  offline         unisex     clothes
# 8               n  central & western   online          women   bath_body
# 9               n           sai kung   online          women     clothes
# 10              n  central & western   online         unisex   bath_body
# 11              n            islands   online         unisex     clothes
# 12              n         kwai tsing   online         unisex        home
# 13              n          tsuen wan   online         unisex   bath_body
# 14              n       kowloon city   online         unisex     clothes
# 15              n           wan chai   online         unisex        home
# 16              n            islands   online          women   accessory
# 17              n            islands  offline         unisex     clothes
# 18              n          kwun tong   online         unisex        wine
# 19              n      yau tsim mong  offline         unisex     clothes

# %%
from sklearn.preprocessing import OneHotEncoder
from sklearn.preprocessing import MinMaxScaler
from sklearn.compose import ColumnTransformer
from sklearn.pipeline import Pipeline
from imblearn.over_sampling import SMOTE

def encode_data(data_df):
    categorical_ord_enc = OneHotEncoder(handle_unknown='ignore')
    numerical_enc = MinMaxScaler()
    preprocessor = ColumnTransformer([
        ('num_minmax_encoded', numerical_enc, ['price', 'final_price','quantity','age']),
        ('categorical_encoded', categorical_ord_enc, ['vendor','product_cat','gender','product_gender','premium_status'])],
        remainder = "passthrough")
    return preprocessor

# %%
data_encoded = encode_data(data)
data_encoded
# Out:
# ColumnTransformer(remainder='passthrough',
#                   transformers=[('num_minmax_encoded', MinMaxScaler(),
#                                  ['price', 'final_price', 'quantity', 'age']),
#                                 ('categorical_encoded',
#                                  OneHotEncoder(handle_unknown='ignore'),
#                                  ['vendor', 'product_cat', 'gender',
#                                   'product_gender', 'premium_status'])])
